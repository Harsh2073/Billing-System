# %%
amt=0
tamt=0
print("Wlcome to the Toy World\n")
print("Board Games:1\n")
print("Soft Toys:2\n")
print("Sports Wear:3\n")
print("Equipments:4\n")
print("Exit:5\n")
c="Y"
while(c=="Y"):
    print("Press 1 for Board Games\n")
    print("Press 2 for Soft Toys\n")
    print("Press 3 for Sports Wear\n")
    print("Press 4 for Equipments\n")
    print("Press 5 for Exit\n")
    print("Enter your choice:\n")
    ch=int(input())
    if(ch==1):
        print("Welocme to Board Games arena\n")
        print("Board Games\t\t\tPrice(in Rs)\n")
        print("1.Snakes and ladder\t\t\t150\n")
        print("2.Ludo\t\t\t\t\t150\n")
        print("3.Bussiness\t\t\t\t200\n")
        print("4.Dart\t\t\t\t\t200\n")
        print("5.Chess\t\t\t\t\t250\n")
        print("6.Checkers\t\t\t\t250\n")
        print("7.Board combo\t\t\t\t350")
        choice="Y"
        while(choice=="Y"):
            print("Choose your prefered game from the above list by entering number:")
            bg=int(input())
            print("Enter quntity of purchase:")
            tbg=int(input())
            if(bg==1 or bg==2):
                amt=tbg*150
            if(bg==3 or bg==4):
                amt=tbg*200
            if(bg==5 or bg==6):
                amt=tbg*250
            if(bg==7):
                amt=tbg*350
            tamt=tamt+amt
            print("Do you want to buy more games?Enter Y/N\n")
            choice=input()
    if(ch==2):
        print("Welocme to Soft World\n")
        print("Soft Toys\t\t\tPrice(in Rs)\n")
        print("1.Soft Toys Keychains\t\t\t150\n")
        print("2.Soft Toys\t\t\t\t150\n")
        print("3.Character Soft Toys\t\t\t200\n")
        print("4.Barbie\t\t\t\t200\n")
        print("5.Soft Toy Pillows\t\t\t250\n")
        print("6.Teddy Bears\t\t\t\t250\n")
        print("7.Combo combo\t\t\t\t350")
        choice="Y"
        while(choice=="Y"):
            print("Choose your prefered game from the above list by entering number:")
            st=int(input())
            print("Enter quntity of purchase:")
            tst=int(input())
            if(st==1 or st==2):
                amt=tst*150
            if(st==3 or st==4):
                amt=tst*200
            if(st==5 or st==6):
                amt=tst*250
            if(st==7):
                amt=tst*350
            tamt=tamt+amt
            print("Do you want to buy more toys?Enter Y/N\n")
            choice=input()
    if(ch==3):
        print("Welocme to Sport Fashion\n")
        print("Sports Wear\t\t\tPrice(in Rs)\n")
        print("1.Cycling Gloves\t\t\t150\n")
        print("2.Tracking Pants\t\t\t150\n")
        print("3.Cricket suit\t\t\t\t200\n")
        print("4.Swimming suit\t\t\t\t200\n")
        print("5.Sport tshirt\t\t\t\t250\n")
        print("6.sports Shoes\t\t\t\t250\n")
        print("7.Combo kit(any 1 sport)\t\t350")
        choice="Y"
        while(choice=="Y"):
            print("Choose your prefered game from the above list by entering number:")
            sw=int(input())
            print("Enter quantity of purchase:")
            tsw=int(input())
            if(sw==1 or sw==2):
                amt=tsw*150
            if(sw==3 or sw==4):
                amt=tsw*200
            if(sw==5 or sw==6):
                amt=tsw*250
            if(sw==7):
                amt=tsw*350
            tamt=tamt+amt
            print("Do you want to shop more?Enter Y/N\n")
            choice=input()
    if(ch==4):
        print("Welocme to sport Equiment arena\n")
        print("Sport Equiment\t\t\tPrice(in Rs)\n")
        print("1.Bicycle Seat Cover\t\t\t150\n")
        print("2.Cricket Bat Grip\t\t\t150\n")
        print("3.Swimming glasses\t\t\t200\n")
        print("4.Safty Guards\t\t\t\t200\n")
        print("5.Badminton Rackets\t\t\t250\n")
        print("6.Cricket Bat\t\t\t\t250\n")
        print("7.Kit Bag(Any 1 sport)\t\t\t350")
        choice="Y"
        while(choice=="Y"):
            print("Choose your prefered game from the above list by entering number:")
            se=int(input())
            print("Enter total number of games you want:")
            tse=int(input())
            if(se==1 or se==2):
                amt=tse*150
            if(se==3 or se==4):
                amt=tse*200
            if(se==5 or se==6):
                amt=tse*250
            if(se==7):
                amt=tse*350
            tamt=tamt+amt
            print("Do you want to buy more equiments?Enter Y/N\n")
            choice=input()
    if(ch==5):
        break
    print("Do you want to shop more?Enter Y/N\n")
    c=input()
print("*******Toy World*******\n")
print("*********Bill*********\n")
print("Total cost=Rs.",tamt)
gst=round((14.5/100.0)*tamt)
print("GST=14.5%\n")
print("Total GST=Rs.",gst)
print("Amount to be paid=Rs.",(tamt+gst))
print("Please Visit Again")
# Out:
# Wlcome to the Toy World
#
# Board Games:1
#
# Soft Toys:2
#
# Sports Wear:3
#
# Equipments:4
#
# Exit:5
#
# Press 1 for Board Games
#
# Press 2 for Soft Toys
#
# Press 3 for Sports Wear
#
# Press 4 for Equipments
#
# Press 5 for Exit
#
# Enter your choice:
#
# 2
# Welocme to Soft World
#
# Soft Toys			Price(in Rs)
#
# 1.Soft Toys Keychains			150
#
# 2.Soft Toys				150
#
# 3.Character Soft Toys			200
#
# 4.Barbie				200
#
# 5.Soft Toy Pillows			250
#
# 6.Teddy Bears				250
#
# 7.Combo combo				350
# Choose your prefered game from the above list by entering number:
# 4
# Enter quntity of purchase:
# 1
# Do you want to buy more toys?Enter Y/N
#
# N
# Do you want to shop more?Enter Y/N
#
# Y
# Press 1 for Board Games
#
# Press 2 for Soft Toys
#
# Press 3 for Sports Wear
#
# Press 4 for Equipments
#
# Press 5 for Exit
#
# Enter your choice:
#
# 1
# Welocme to Board Games arena
#
# Board Games			Price(in Rs)
#
# 1.Snakes and ladder			150
#
# 2.Ludo					150
#
# 3.Bussiness				200
#
# ...
